# %%
"""
Lol what to write!
Owner:- Divyansh Bhati
Copyrights:- Divyansh Bhati
Lel:- Divyansh Bhati
"""

# Front-end:- Python(Anaconda-Navigator)
# Back-end:- Python(Python-Module-urllib and os) [imported below]
# Telegram:- ARROWDIV
# Out:
# '\nLol what to write!\nOwner:- Divyansh Bhati\nCopyrights:- Divyansh Bhati\nLel:- Divyansh Bhati\n'

# %%
import pandas as pd
import matplotlib.pyplot as Mat
import numpy as np
import urllib
import os

# %%
url = "https://raw.githubusercontent.com/DivyanshAlSaud/NSE-Stocks-Project/main/High-Low-NSE.csv"
file_path = os.path.join("data","High-Low-NSE")

# %%
os.makedirs(file_path, exist_ok=True)
csv_path = os.path.join(file_path,"High-Low-NSE.csv")
urllib.request.urlretrieve(url,csv_path)
# Out:
# ('data\\High-Low-NSE\\High-Low-NSE.csv',
#  <http.client.HTTPMessage at 0x28903952490>)

# %%
DataHighLow = pd.read_csv(csv_path)

# %%
DataHighLow
# Out:
#           SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0      20MICRONS     EQ     60.90     62.75     60.00     61.00     61.10
# 1     21STCENMGM     EQ     49.20     49.20     49.20     49.20     49.20
# 2        3MINDIA     EQ  24800.00  24900.00  24500.00  24863.20  24896.40
# 3         3PLAND     BE     14.00     14.00     13.20     13.90     13.90
# 4         5PAISA     EQ    462.00    479.00    455.65    476.05    472.00
# ...          ...    ...       ...       ...       ...       ...       ...
# 2110      ZOMATO     EQ    137.30    140.50    137.00    138.00    138.20
# 2111        ZOTA     EQ    387.00    409.80    382.05    395.70    396.00
# 2112       ZUARI     BE    130.45    130.45    125.25    127.85    129.00
# 2113   ZUARIGLOB     BE    132.00    134.95    130.05    130.90    130.85
# 2114   ZYDUSWELL     EQ   2370.00   2378.00   2306.60   2320.95   2320.00
#
#       PREVCLOSE  TOTTRDQTY     TOTTRDVAL    TIMESTAMP  TOTALTRADES  \
# ...

# %%
# Use your mind to fool external 
"""
Hint:- 
1. Use .min() and .max() in high and low columns.
2. Use .min() and .max() in last and prevclose
3. Use your cerebrum(brain).
"""
# Out:
# '\nHint:- \n1. Use .min() and .max() in high and low columns.\n2. Use .min() and .max() in last and prevclose\n3. Use your cerebrum(brain).\n'
